# %%
"""
llm_judge_comparative_metrics document example: 

{
  "_id": {
    "$oid": "693084f7886ac3b0d31b3145"
  },
  "experiment_name": "LLM_Judge_gpt-4o-mini",
  "calculation_timestamp": {
    "$date": "2025-12-03T18:44:07.180Z"
  },
  "STI_metrics": {
    "coherence": {
      "mean": 4.57,
      "std": 0.52,
      "count_max_score": 1385,
      "total_samples": 2400
    },
    "specificity": {
      "mean": 4.33,
      "std": 0.95,
      "count_max_score": 1157,
      "total_samples": 2400
    },
    "informativeness": {
      "mean": 4.51,
      "std": 0.54,
      "count_max_score": 1276,
      "total_samples": 2400
    },
    "relevance": {
      "mean": 4.96,
      "std": 0.19,
      "count_max_score": 2315,
      "total_samples": 2400
    },
    "Understandability": {
      "mean": 4.64,
      "std": 0.5,
      "count_max_score": 1565,
      "total_samples": 2400
    }
  },
  "MTI_metrics": {
    "coherence": {
      "mean": 4.63,
      "std": 0.5,
      "count_max_score": 1534,
      "total_samples": 2400
    },
    "specificity": {
      "mean": 4.37,
      "std": 0.96,
      "count_max_score": 1274,
      "total_samples": 2400
    },
    "informativeness": {
      "mean": 4.55,
      "std": 0.55,
      "count_max_score": 1384,
      "total_samples": 2400
    },
    "relevance": {
      "mean": 4.96,
      "std": 0.2,
      "count_max_score": 2303,
      "total_samples": 2400
    },
    "Understandability": {
      "mean": 4.71,
      "std": 0.47,
      "count_max_score": 1720,
      "total_samples": 2400
    }
  },
  "differences": {
    "coherence": {
      "mean_difference": 0.06,
      "better_approach": "MTI"
    },
    "specificity": {
      "mean_difference": 0.04,
      "better_approach": "MTI"
    },
    "informativeness": {
      "mean_difference": 0.04,
      "better_approach": "MTI"
    },
    "relevance": {
      "mean_difference": 0,
      "better_approach": "TIE"
    },
    "Understandability": {
      "mean_difference": 0.07,
      "better_approach": "MTI"
    }
  },
  "overall_statistics": {
    "STI": {
      "mean": 4.6,
      "std": 0.62,
      "count_max_score": 7698,
      "total_samples": 12000
    },
    "MTI": {
      "mean": 4.64,
      "std": 0.62,
      "count_max_score": 8215,
      "total_samples": 12000
    },
    "mean_difference": 0.04,
    "better_approach_overall": "MTI"
  },
  "comparative_summary": {
    "metrics_won_by_MTI": 4,
    "metrics_won_by_STI": 0,
    "metrics_tied": 1,
    "dominant_approach": "MTI"
  }
}
"""
