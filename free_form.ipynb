# %%
import json

# %%
with open("data/Free_Form_Generation.json", 'r') as file:
    data = json.load(file)

# %%
data.keys()
# Out:
# dict_keys(['034', '038', '039', '035', '032', '033', '030', '031', '036', '041', '040', '037'])

# %%
len(data.keys())
# Out:
# 12

# %%
data['034'].keys()
# Out:
# dict_keys(['instance', 'sample'])

# %%
len(data['034'])
# Out:
# 2

# %%
len(data['034']['instance'])
# Out:
# 200

# %%
len(data['034']['sample'])
# Out:
# 1687
